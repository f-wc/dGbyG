# %%
from dGbyG.data_processor.pubchem_data import pubchem_gz_to_db

# %%
pubchem_gz_to_db('CID-SMILES.gz', 'CID-SMILES.db')
# Out:
# Inserted 10,000,000 rows, elapsed 21.8s, speed 459137 rows/s
# Inserted 20,000,000 rows, elapsed 43.5s, speed 459596 rows/s
# Inserted 30,000,000 rows, elapsed 64.6s, speed 464320 rows/s
# Inserted 40,000,000 rows, elapsed 84.5s, speed 473326 rows/s
# Inserted 50,000,000 rows, elapsed 105.0s, speed 476142 rows/s
# Inserted 60,000,000 rows, elapsed 126.3s, speed 474908 rows/s
# Inserted 70,000,000 rows, elapsed 145.6s, speed 480796 rows/s
# Inserted 80,000,000 rows, elapsed 164.2s, speed 487137 rows/s
# Inserted 90,000,000 rows, elapsed 186.2s, speed 483251 rows/s
# Inserted 100,000,000 rows, elapsed 209.2s, speed 478092 rows/s
# Inserted 110,000,000 rows, elapsed 243.9s, speed 450967 rows/s
# Inserted 120,000,000 rows, elapsed 269.2s, speed 445710 rows/s
# Done! Total 124,001,167 rows inserted, database file: /zhongj/dgbyg_thermoinfer_protocol/dGbyG/data/PubChem/CID-SMILES.db
