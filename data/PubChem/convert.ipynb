# %%
from dGbyG.data_processor.pubchem_data import pubchem_gz_to_db

# %%
pubchem_gz_to_db('CID-SMILES.gz', 'CID-SMILES.db')
# Out:
# Inserted 10,000,000 rows, elapsed 22.3s, speed 448563 rows/s
# Inserted 20,000,000 rows, elapsed 43.6s, speed 459112 rows/s
# Inserted 30,000,000 rows, elapsed 65.1s, speed 461172 rows/s
# Inserted 40,000,000 rows, elapsed 84.8s, speed 471447 rows/s
# Inserted 50,000,000 rows, elapsed 105.8s, speed 472559 rows/s
# Inserted 60,000,000 rows, elapsed 126.8s, speed 473044 rows/s
# Inserted 70,000,000 rows, elapsed 145.7s, speed 480357 rows/s
# Inserted 80,000,000 rows, elapsed 164.4s, speed 486536 rows/s
# Inserted 90,000,000 rows, elapsed 186.4s, speed 482784 rows/s
# Inserted 100,000,000 rows, elapsed 210.9s, speed 474197 rows/s
# Inserted 110,000,000 rows, elapsed 247.8s, speed 443852 rows/s
# Inserted 120,000,000 rows, elapsed 273.0s, speed 439514 rows/s
# Done! Total 123,999,287 rows inserted, database file: /home/zhongj/dgbyg_thermoinfer_protocol/dGbyG/data/PubChem/CID-SMILES.db
