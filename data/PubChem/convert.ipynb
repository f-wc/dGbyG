# %%
from dGbyG.data_processor.pubchem_data import pubchem_gz_to_db

# %%
pubchem_gz_to_db('CID-SMILES.gz', 'CID-SMILES.db')
# Out:
# 已插入 10,000,000 行，耗时 21.6 秒，速度 462507 行/秒
# 已插入 20,000,000 行，耗时 43.3 秒，速度 461945 行/秒
# 已插入 30,000,000 行，耗时 64.2 秒，速度 467097 行/秒
# 已插入 40,000,000 行，耗时 83.7 秒，速度 477693 行/秒
# 已插入 50,000,000 行，耗时 104.1 秒，速度 480269 行/秒
# 已插入 60,000,000 行，耗时 125.1 秒，速度 479757 行/秒
# 已插入 70,000,000 行，耗时 144.3 秒，速度 484985 行/秒
# 已插入 80,000,000 行，耗时 162.9 秒，速度 491154 行/秒
# 已插入 90,000,000 行，耗时 184.5 秒，速度 487827 行/秒
# 已插入 100,000,000 行，耗时 207.0 秒，速度 483024 行/秒
# 已插入 110,000,000 行，耗时 241.2 秒，速度 456108 行/秒
# 已插入 120,000,000 行，耗时 266.1 秒，速度 450953 行/秒
# 完成！共插入 122,454,458 行，数据库文件：/home/fanwc/projects/dGbyG/data/PubChem/CID-SMILES.db
